# %%
import pandas as pd
# %matplotlib inline

# %%
data1 = pd.read_csv("fire_incidents.csv", index_col="neighborhood")
data1
# Out:
#                      call_no  incident_type  \
# neighborhood
# Bloomfield        F130000539          112.0
# Morningside       F130000714          118.0
# Shadyside         F130000772          118.0
# Brighton Heights  F130001276          142.0
# NaN               F130001288          131.0
# ...                      ...            ...
# NaN               F200070433          130.0
# NaN               F200070681          151.0
# Hazelwood         F200071129          113.0
# NaN               F200071382          113.0
# Chateau           F200071501          131.0
#
#                                              type_description  \
# neighborhood
# Bloomfield        Fires in structure other than in a building
# Morningside                  Trash or rubbish fire, contained
# Shadyside                    Trash or rubbish fire, contained
# Brighton Heights        Brush or brush-and-grass mixture fire
# NaN                                    Passenger vehicle fire
# ...

# %%
data_filtered=data.dropna()
data_filtered
# Out:
#                               call_no  incident_type  \
# neighborhood
# Bloomfield                 F130000539          112.0
# Morningside                F130000714          118.0
# Shadyside                  F130000772          118.0
# Brighton Heights           F130001276          142.0
# Central Business District  F130001631          115.0
# ...                               ...            ...
# Central Business District  F200069778          113.0
# West Oakland               F200070145          131.0
# Bluff                      F200070149          100.0
# Hazelwood                  F200071129          113.0
# Chateau                    F200071501          131.0
#
#                                                             type_description  \
# neighborhood
# Bloomfield                       Fires in structure other than in a building
# Morningside                                 Trash or rubbish fire, contained
# ...

# %%
data_dropped = data_filtered.drop(columns = ['incident_type','type_description','address','alarm_time','alarms','primary_unit','census_tract','council_district','ward','tract','public_works_division','pli_division','police_zone','fire_zone','longitude','latitude'])
data_dropped
# Out:
#                               call_no
# neighborhood
# Bloomfield                 F130000539
# Morningside                F130000714
# Shadyside                  F130000772
# Brighton Heights           F130001276
# Central Business District  F130001631
# ...                               ...
# Central Business District  F200069778
# West Oakland               F200070145
# Bluff                      F200070149
# Hazelwood                  F200071129
# Chateau                    F200071501
#
# [6389 rows x 1 columns]

# %%
#popular_fires=data_filtered.groupby("neighborhood").count()
data_dropped.groupby('neighborhood').count().nsmallest(10, 'call_no', keep='all').plot.bar(y='call_no', rot=90, use_index=True)
